# %% [markdown]
# <a href="https://colab.research.google.com/github/dpierso1/Pierson_IT533/blob/main/Week_9_Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets 
from sklearn.cluster import KMeans 
airline = pd.read_csv("https://raw.githubusercontent.com/dpierso1/Pierson_IT533/main/airline_passenger_satisfaction.csv", encoding="ISO-8859-1") #USE YOUR OWN GITHUB LINK HERE
airline.dropna(inplace=True) 
airline_data.dropna(inplace=True)
airline.head()
# Out:
#    ID  Gender  Age CustomerType TypeOfTravel     Class  FlightDistance  \
# 0   1    Male   48   First-time     Business  Business             821
# 1   2  Female   35    Returning     Business  Business             821
# 2   3    Male   41    Returning     Business  Business             853
# 3   4    Male   50    Returning     Business  Business            1905
# 4   5  Female   49    Returning     Business  Business            3470
#
#    DepartureDelay  ArrivalDelay  EaseOfOnlineBooking  ...  On-boardService  \
# 0               2           5.0                    3  ...                3
# 1              26          39.0                    2  ...                5
# 2               0           0.0                    4  ...                3
# 3               0           0.0                    2  ...                5
# 4               0           1.0                    3  ...                3
#
#    SeatComfort  LegRoom  Cleanliness  FoodAndDrink  In-flightWifi  \
# ...

# %%
airline_data = pd.read_csv('https://raw.githubusercontent.com/dpierso1/Pierson_IT533/main/airline_passenger_satisfaction.csv')
airline_data = airline_data.set_index('CustomerType')
airline_data.head()
# Out:
#               ID  Gender  Age TypeOfTravel     Class  FlightDistance  \
# CustomerType
# First-time     1    Male   48     Business  Business             821
# Returning      2  Female   35     Business  Business             821
# Returning      3    Male   41     Business  Business             853
# Returning      4    Male   50     Business  Business            1905
# Returning      5  Female   49     Business  Business            3470
#
#               DepartureDelay  ArrivalDelay  EaseOfOnlineBooking  \
# CustomerType
# First-time                 2           5.0                    3
# Returning                 26          39.0                    2
# Returning                  0           0.0                    4
# Returning                  0           0.0                    2
# Returning                  0           1.0                    3
#
#               Check-inService  ...  On-boardService  SeatComfort  LegRoom  \
# CustomerType                   ...
# ...

# %%
new_airline = airline[['PriceUSD', 'Age', 'FlightDistance', 'ArrivalDelay']]

from sklearn.preprocessing import StandardScaler 

sc = StandardScaler() 
new_airline_array = sc.fit_transform(new_airline.values) 
standardized_airline = pd.DataFrame(new_airline_array, index = new_airline.index, columns = new_airline.columns) 
new_airline_array
# Out:
# array([[-0.39624654,  0.56746004, -0.36168923, -0.26472808],
#        [-0.39729868, -0.29282143, -0.36168923,  0.61325927],
#        [-0.03038478,  0.10423155, -0.32959086, -0.39384386],
#        ...,
#        [-0.63562278, -0.02811944, -0.71577443, -0.26472808],
#        [-0.40982863,  1.16303952, -0.55227333, -0.39384386],
#        [ 0.23810047,  1.758619  ,  0.47387158, -0.26472808]])

# %%
# Assign the scaled data to a DataFrame & use the index and columns arguments to keep your original indices and column names:
new_airline_norm = pd.DataFrame(new_airline_array, index=new_airline.index, columns=new_airline.columns)
new_airline_norm
# Out:
#         PriceUSD       Age  FlightDistance  ArrivalDelay
# 0      -0.396247  0.567460       -0.361689     -0.264728
# 1      -0.397299 -0.292821       -0.361689      0.613259
# 2      -0.030385  0.104232       -0.329591     -0.393844
# 3       0.539106  0.699811        0.725643     -0.393844
# 4       2.788790  0.633636        2.295454     -0.368021
# ...          ...       ...             ...           ...
# 126121 -0.749668  0.236583       -0.715774     -0.135612
# 126122 -0.733171 -1.153103       -0.676655     -0.316374
# 126123 -0.635623 -0.028119       -0.715774     -0.264728
# 126124 -0.409829  1.163040       -0.552273     -0.393844
# 126125  0.238100  1.758619        0.473872     -0.264728
#
# [125743 rows x 4 columns]

# %%
# On to clustering with kMeans. Note that the variable "labels" is an array which specifies which cluster each dog belongs to:

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, ).fit(new_airline_norm)
labels = kmeans.labels_
labels
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([1, 2, 1, ..., 1, 1, 1], dtype=int32)

# %%
groups = {0: [], 1: [], 2: []} # We have 3 clusters
i = 0                                       # Initializing the row counter
for index, row in new_airline.iterrows():      # We are now going through each row in dog_data
    groups[labels[i]].append(index)         # and appending the cluster labels/ numbers to each index
    i += 1

## Now we make a pretty list:

for key, value in groups.items():           # the key is the cluster number and the value is the names of the dogs
    print ('CLUSTER %i' % key)
    for Class in value:
        print("    %s" % Class)
    print('\n')
# Out:
# Streaming output truncated to the last 5000 lines.
#     112590
#     112597
#     112598
#     112599
#     112601
#     112602
#     112604
#     112610
#     112615
#     112617
#     112620
#     112621
#     112622
#     112623
#     112625
#     112632
#     112634
#     112635
#     112636
#     112637
#     112638
#     112639
#     112641
#     112645
#     112649
#     112650
#     112654
#     112658
#     112659
#     112663
#     112665
#     112670
#     112681
#     112684
#     112688
#     112690
#     112692
#     112693
#     112694
#     112699
#     112702
#     112704
#     112706
#     112707
#     112710
#     112712
#     112713
#     112714
#     112716
#     112717
#     112718
#     112719
#     112720
#     112724
#     112726
#     112730
#     112731
#     112739
#     112740
#     112741
#     112744
#     112750
#     112753
#     112754
#     112757
#     112759
#     112760
#     112766
#     112768
#     112771
#     112776
#     112777
# ...

# %%
airline = datasets.load_airline() 
airline
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/sklearn/datasets/__init__.py in __getattr__(name)
#     157     try:
# --> 158         return globals()[name]
#     159     except KeyError:
#
# KeyError: 'load_airline'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-bc51c2eeb25a> in <cell line: 1>()
# ----> 1 airline = datasets.load_airline()
#       2 airline
#
# /usr/local/lib/python3.9/dist-packages/sklearn/datasets/__init__.py in __getattr__(name)
#     159     except KeyError:
#     160         # This is turned into the appropriate ImportError
# --> 161         raise AttributeError
#
# AttributeError:

# %%
# Map encoded target values to target names
def map_target(target_num):
    return new_airline.target_names[int(target_num)]

new_airline_target_name = new_airline_target.apply(map_target, 1)
new_airline_target_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-0a6c03061e83> in <cell line: 5>()
#       3     return new_airline.target_names[int(target_num)]
#       4
# ----> 5 new_airline_target_name = new_airline_target.apply(map_target, 1)
#       6 new_airline_target_name
#
# NameError: name 'new_airline_target' is not defined
